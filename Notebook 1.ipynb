# %%
from bs4 import BeautifulSoup
import time
import re
import time
import requests 
import random
import yagmail
cookies_list = [ {
     'session-id': '258-7457033-0925942',
    'session-id-time': '2082787201l',
    'i18n-prefs': 'INR',
    'ubid-acbin': '259-6470181-4344157',
    'csm-hit': 'tb:D5DTF17ZCAPW0AGTW6EJ+s-P3B7MN56VEY4VZ7HMT7P|1685341065958&t:1685341065958&adb:adblk_no',
    'session-token': 'IDkk7KqRlXRmR97+RsIp2S6jEjMT8/i1vn5fHE147IV3goxUAyT18JLVc65gI+wfxFt99tmFlzVLdz3mPJqT7knGEqMePRHoMWssJxZ1DAVnLjJS07wRhy+JbBcytyKx1v78j39107qK9a9flkI3ddJzIZbcN/U8Nly2Gzj+JgAcAC1ql5o6nULjHzH7sZMnALYfR6zhfk2c3Iq5fIaPHFlXEVSeTt6jvZNUF09O5PA='
},{
    'session-id': '258-9580256-0592113',
    'session-id-time': '2082787201l',
    'i18n-prefs': 'INR',
    'ubid-acbin': '261-1290505-2290605',
    'session-token': 'NcdcpqZoR3NJfyBUJG2gLgNjo9Aj9S4JQEm3cPbcBC8sazNWl93SRdKPHv8FMuFZ7UTiiuYNzMtV9Z/HzLq4696R6tbWwMlX7VzJqasoNZpb/RibmdRJIriI67i3fpZPpfLk11Di//6x4TOny7unh4jzOP8ZPq7+2aWLVayzQJ0pxJ23WjHkmyZeRJNAbZNEWWUj21i7Hja2apB7qisjqI4r4Av8IbwfyecQdzYY7po=',
    'csm-hit': 'tb:s-B4KJVN545Q0NG9AB9VHY|1685729333233&t:1685729335707&adb:adblk_no',
},{
    'session-id': '257-5723199-4596841',
    'session-id-time': '2082787201l',
    'i18n-prefs': 'INR',
    'ubid-acbin': '259-4159015-4374358',
    'session-token': 'j36Cy29OMwLWAYYEL4zcbVaZAh8aB6aYPOUvuUma06j7UiFb7U8u2UYI8D9NE85ZVKcMVNUvie5D64zuFBp8MZ4uURN8Rr5/fb1S2JqId06FGw8egH4y3b5Arz1yu11EZuOTTJf6bPvBstsSEr1H32TH1yGC5Z30L7LL+14d+PKeVayNHmPGVElkB8B+G2CPhtwh1q+vUWvi/AvLXFtYu9MNohxn9yTDXJ4/Qu2YEWA=',
    'csm-hit': 'tb:VMFBXNX6B5X6PKX99DGK+s-Z2VVR5GC1G39DATECCVE|1685340198881&t:1685340198881&adb:adblk_no',
}]

headers_list = [{
    'authority': 'www.amazon.in',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'en-US,en;q=0.9',
    'user-agent': 'Mozilla/5.0 (Windows; U; Windows NT 10.1; WOW64) AppleWebKit/537.46 (KHTML, like Gecko) Chrome/49.0.2856.184 Safari/600',
 
},{
    'authority': 'www.amazon.in',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'en-US,en;q=0.9',
    'user-agent': 'Mozilla/5.0 (Xwayland; Linux i386; rv:109.0) Gecko/20100101 Firefox/45.0',
 
},{
    'authority': 'www.amazon.in',
    'accept': 'text/html,application/xhtml+xml,application/xml;',
    'sec-ch-dpr': '1.25',
    'service-worker-navigation-preload': 'true',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 9_2_8; en-US) AppleWebKit/603.23 (KHTML, like Gecko) Chrome/55.0.3562.235 Safari/602',
}]
headers=random.choice(headers_list)
cookies=random.choice(cookies_list)
yag = yagmail.SMTP("sourjyendra@7sages.co.in", oauth2_file="ret.json")
subject = f"Out of stock notification for Cosmix"

# Adding Content and sending it
to="srinivasanms@7sages.co.in"
to2="retail@cosmix.in"
to3="soorya@cosmix.in"
params = {
    'th': '1'
}
infos="ASIN    ||||||         Merchant   ||||||     Product Name"
names=[]
urls=[]
with open('asin.txt') as user_file:
  ufile = user_file.read()
urls=ufile.split('\n')
with open('name.txt') as user_file:
  ufile = user_file.read()
names=ufile.split('\n')
if time.localtime().tm_hour%6:
    exit()
else:
    for i in range(len(urls)):
        print(i)
        url=urls[i]
        name=names[i]
        url='https://amazon.in/dp/'+str(url)
        response = requests.get(
                        url,
                        headers=headers,
                        cookies=cookies,
                        params=params
                )
        
        soup = BeautifulSoup(response.content, "lxml" )
        try:
            if soup.select("#merchant-info>a"):
                merchant = soup.select_one("#merchant-info>a").get_text()
            else:
                merchant = soup.select_one("#outOfStock>div>div>span").get_text()
            print(merchant)
            print(soup.select_one("#contextualIngressPt").get_text())
            r1=re.match(r"Primarc Pecan",merchant)
            if not r1:
                infos=infos+f"\n{urls[i]}        ||||||    {merchant}    ||||||     {name}"
        except:pass
        time.sleep(random.randint(2,6))
    body = f"The following ASINs are out of stock for seller Primarc Pecan and are being sold by the merchants mentioned below\n\n{infos}"
    yag.send(to=[to,to2,to3],subject = subject, contents = body)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6ab6b274-edd0-432c-862e-a92a010d62d0' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
